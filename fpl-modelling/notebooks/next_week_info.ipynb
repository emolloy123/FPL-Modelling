# %% [markdown]
# # Load Kedro

# %%
# %reload_ext kedro.ipython
# Out:
# [10/16/25 20:29:05] INFO     Registered line magic '%reload_kedro'                                   ]8;id=858059;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=976124;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=116009;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=235533;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py#65\65]8;;\
# ...

# %%
catalog.load("teams")
# Out:
#                     INFO     Loading data from teams (SQLTableDataset)...                      ]8;id=34770;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=906470;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          code  draw  form  loss       team_name  played  points  position  \
# team_id
# 1           3     0  None     0         Arsenal       0       0         1
# 2           7     0  None     0     Aston Villa       0       0        13
# 3          90     0  None     0         Burnley       0       0        18
# 4          91     0  None     0     Bournemouth       0       0         4
# ...

# %%
p_nw = catalog.load("player_info_at_gameweek")
# Out:
#                     INFO     Loading data from player_info_at_gameweek (SQLQueryDataset)...    ]8;id=572816;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=480211;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\

# %%
p_nw['accumulated_minutes'].min()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# np.int64(1)

# %%
p = catalog.load("players")
# Out:
#                     INFO     Loading data from players (SQLTableDataset)...                    ]8;id=415830;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=206711;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\

# %%
p_hist = catalog.load("players_hist")
# Out:
#                     INFO     Loading data from players_hist (SQLTableDataset)...               ]8;id=451279;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=944569;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\

# %%
p['chance_of_playing_next_round']
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# player_id
# 1        NaN
# 2        NaN
# 3        0.0
# 4        NaN
# 5      100.0
#        ...
# 663      NaN
# 682      NaN
# 695      NaN
# 709      NaN
# 720      NaN
# Name: chance_of_playing_next_round, Length: 743, dtype: float64

# %%
f = catalog.load("fixtures")
# Out:
#                     INFO     Loading data from fixtures (SQLTableDataset)...                   ]8;id=174859;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=888748;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\

# %%
catalog.load("positions")
# Out:
#                     INFO     Loading data from positions (SQLTableDataset)...                  ]8;id=826299;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=352703;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              plural_name plural_name_short position_name singular_name_short  \
# position_id
# 1            Goalkeepers               GKP    Goalkeeper                 GKP
# 2              Defenders               DEF      Defender                 DEF
# 3            Midfielders               MID    Midfielder                 MID
# 4               Forwards               FWD       Forward                 FWD
#
# ...

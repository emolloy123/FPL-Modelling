# %% [markdown]
# # Load Kedro

# %%
# %reload_ext kedro.ipython
# Out:
# [12/01/25 20:52:12] INFO     Registered line magic '%reload_kedro'                                   ]8;id=754954;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=466842;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=519770;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=850460;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py#65\65]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=638220;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=983248;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py#180\180]8;;\
#                              /Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling.
#                              To set a different path, run '%reload_kedro <project_root>'
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=742842;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=316072;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro_telemetry/plugin.py#243\243]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     INFO     Kedro project fpl_modelling                                            ]8;id=710392;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=48150;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py#146\146]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=226877;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=611986;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py#147\147]8;;\
#                              'pipelines'
#                     INFO     Registered line magic 'run_viz'                                        ]8;id=780629;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=98828;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/ipython/__init__.py#153\153]8;;\

# %% [markdown]
# # Imports

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import f_oneway

# %%
df = catalog.load("players_hist_merged")
df
# Out:
#                     INFO     Loading data from players_hist_merged (SQLQueryDataset)...        ]8;id=593968;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=380487;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       player_id         web_name first_name  second_name  team_id  \
# 0             1             Raya      David  Raya Martín        1
# 1             1             Raya      David  Raya Martín        1
# 2             1             Raya      David  Raya Martín        1
# 3             1             Raya      David  Raya Martín        1
# 4             1             Raya      David  Raya Martín        1
# ...         ...              ...        ...          ...      ...
# 9568        753            Ruddy       John        Ruddy       15
# 9569        754  George Hemmings     George     Hemmings        2
# 9570        754  George Hemmings     George     Hemmings        2
# 9571        755            Lacey       Shea        Lacey       14
# 9572        755            Lacey       Shea        Lacey       14
#
#      players_team  was_home  players_team_score  opponent_team_score  round  \
# 0         Arsenal         0                   1                    0      1
# 1         Arsenal         1                   5                    0      2
# 2         Arsenal         0                   0                    1      3
# 3         Arsenal         1                   3                    0      4
# 4         Arsenal         1                   1                    1      5
# ...           ...       ...                 ...                  ...    ...
# 9568    Newcastle         0                   4                    1     13
# 9569  Aston Villa         0                   2                    1     12
# 9570  Aston Villa         1                   1                    0     13
# 9571      Man Utd         1                   0                    1     12
# 9572      Man Utd         0                   2                    1     13
#
#       ...  position_id  position_name  position_name_abbr  cumsum_minutes  \
# 0     ...            1     Goalkeeper                 GKP              90
# 1     ...            1     Goalkeeper                 GKP             180
# 2     ...            1     Goalkeeper                 GKP             270
# 3     ...            1     Goalkeeper                 GKP             360
# 4     ...            1     Goalkeeper                 GKP             450
# ...   ...          ...            ...                 ...             ...
# 9568  ...            1     Goalkeeper                 GKP               0
# 9569  ...            3     Midfielder                 MID               0
# 9570  ...            3     Midfielder                 MID               0
# 9571  ...            3     Midfielder                 MID               0
# 9572  ...            3     Midfielder                 MID               0
#
#       cumsum_points  cumsum_ict_index  cumsum_transfers_in  \
# 0                10               4.9                    0
# 1                16               6.2               277339
# 2                18               9.2               424078
# 3                24              10.5               713119
# 4                26              12.6               811219
# ...             ...               ...                  ...
# 9568              0               0.0                  110
# 9569              0               0.0                    0
# 9570              0               0.0                   47
# 9571              0               0.0                    0
# 9572              0               0.0                   45
#
#      cumsum_transfers_out  next_week_is_home next_week_opponent_team_name
# 0                       0                  1                        Leeds
# 1                   58680                  0                    Liverpool
# 2                  217730                  1                Nott'm Forest
# 3                  335482                  1                     Man City
# 4                  443368                  0                    Newcastle
# ...                   ...                ...                          ...
# 9568                   10                  1                        Spurs
# 9569                    0                  1                       Wolves
# 9570                    7                  0                     Brighton
# 9571                    0                  0               Crystal Palace
# 9572                    3                  1                     West Ham
#
# [9573 rows x 28 columns]

# %%
df[df['round']==13]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       player_id         web_name first_name            second_name  team_id  \
# 12            1             Raya      David            Raya Martín        1
# 25            2     Arrizabalaga       Kepa  Arrizabalaga Revuelta        1
# 38            3             Hein       Karl                   Hein        1
# 51            4          Setford      Tommy                Setford        1
# 64            5          Gabriel    Gabriel   dos Santos Magalhães        1
# ...         ...              ...        ...                    ...      ...
# 9563        751        Akhamrich      Yusuf              Akhamrich       18
# 9566        752      Golambeckis    Airidas            Golambeckis       19
# 9568        753            Ruddy       John                  Ruddy       15
# 9570        754  George Hemmings     George               Hemmings        2
# 9572        755            Lacey       Shea                  Lacey       14
#
#      players_team  was_home  players_team_score  opponent_team_score  round  \
# 12        Arsenal         0                   1                    1     13
# 25        Arsenal         0                   1                    1     13
# 38        Arsenal         0                   1                    1     13
# 51        Arsenal         0                   1                    1     13
# 64        Arsenal         0                   1                    1     13
# ...           ...       ...                 ...                  ...    ...
# 9563        Spurs         1                   1                    2     13
# 9566     West Ham         1                   0                    2     13
# 9568    Newcastle         0                   4                    1     13
# 9570  Aston Villa         1                   1                    0     13
# 9572      Man Utd         0                   2                    1     13
#
#       ...  position_id  position_name  position_name_abbr  cumsum_minutes  \
# 12    ...            1     Goalkeeper                 GKP            1170
# 25    ...            1     Goalkeeper                 GKP               0
# 38    ...            1     Goalkeeper                 GKP               0
# 51    ...            1     Goalkeeper                 GKP               0
# 64    ...            2       Defender                 DEF             990
# ...   ...          ...            ...                 ...             ...
# 9563  ...            3     Midfielder                 MID               0
# 9566  ...            2       Defender                 DEF               0
# 9568  ...            1     Goalkeeper                 GKP               0
# 9570  ...            3     Midfielder                 MID               0
# 9572  ...            3     Midfielder                 MID               0
#
#       cumsum_points  cumsum_ict_index  cumsum_transfers_in  \
# 12               58              19.7              2395871
# 25                0               0.0                 8509
# 38                0               0.0                 5545
# 51                0               0.0                16264
# 64               81              46.9              3873595
# ...             ...               ...                  ...
# 9563              0               0.0                  174
# 9566              0               0.0                  220
# 9568              0               0.0                  110
# 9570              0               0.0                   47
# 9572              0               0.0                   45
#
#      cumsum_transfers_out  next_week_is_home next_week_opponent_team_name
# 12                1012244                  1                    Brentford
# 25                  62796                  1                    Brentford
# 38                  41919                  1                    Brentford
# 51                  18020                  1                    Brentford
# 64                3576120                  1                    Brentford
# ...                   ...                ...                          ...
# 9563                   52                  0                    Newcastle
# 9566                  110                  0                      Man Utd
# 9568                   10                  1                        Spurs
# 9570                    7                  0                     Brighton
# 9572                    3                  1                     West Ham
#
# [755 rows x 28 columns]

# %%
model_config = catalog.load("params:model_config")[4]
# Out:
#                     INFO     Loading data from params:model_config (MemoryDataset)...          ]8;id=469655;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=836924;file:///Users/eoinmolloy/Documents/Documents/FPL-Modelling/fpl-modelling/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\

# %%
df.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['player_id', 'web_name', 'first_name', 'second_name', 'team_id',
#        'players_team', 'was_home', 'players_team_score', 'opponent_team_score',
#        'round', 'round_minutes', 'round_points', 'transfer_cost',
#        'transfers_balance', 'selected', 'transfers_in', 'transfers_out',
#        'ict_index', 'position_id', 'position_name', 'position_name_abbr',
#        'cumsum_minutes', 'cumsum_points', 'cumsum_ict_index',
#        'cumsum_transfers_in', 'cumsum_transfers_out', 'next_week_is_home',
#        'next_week_opponent_team_name'],
#       dtype='object')

# %%
df[f"next_week_round_points"] = df.groupby('player_id')['round_points'].shift(-1)

# %%
df[df['round']==1]['cumsum_minutes']
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0       90
# 13       0
# 26       0
# 39       0
# 52      90
#         ..
# 8905     0
# 8918     0
# 8931     0
# 8944     0
# 8957     0
# Name: cumsum_minutes, Length: 690, dtype: int64

# %%
# features:
#  num_features: 
#   prev_gameweeks:
#     accumulated_minutes:
#         num_prev_games: 3
#         average_type: ma
#     ict_index:
#         num_prev_games: 3
#         average_type: ema
#  cat_features: 
#   next_gameweek:
#     - next_week_is_home
#     - next_week_opponent_team
